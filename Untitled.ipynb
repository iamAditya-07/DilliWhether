# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('testset.csv');

# %%
data.head()
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# 1        NaN      -9999.0       0       0     28.0          0          0
# 2        NaN      -9999.0       0       0     24.0          0          0
# 3        NaN       1010.0       0       0     24.0          0          0
# 4        NaN       1011.0       0       0     23.0          0          0
#
#     _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# ...

# %%
data.sample(5)
# Out:
#          datetime_utc         _conds   _dewptm   _fog   _hail   _heatindexm  \
# 26119  20010514-21:30           Haze      16.0      0       0          30.9
# 58269  20040427-04:00           Haze      15.0      0       0          31.6
# 48571  20030919-04:00  Partly Cloudy      25.0      0       0          36.0
# 43124  20030516-05:30          Clear       4.0      0       0           NaN
# 96818  20160830-07:00       Overcast      26.0      0       0          37.4
#
#         _hum   _precipm   _pressurem   _rain   _snow   _tempm   _thunder  \
# 26119   40.0        NaN       1002.0       0       0     31.0          0
# 58269   36.0        NaN       1010.0       0       0     32.0          0
# 48571   74.0        NaN       1009.0       0       0     30.0          0
# 43124   11.0        NaN       1005.0       0       0     39.0          0
# 96818   79.0        NaN       1004.0       0       0     30.0          0
#
# ...

# %%
data.shape
# Out:
# (100990, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100990 entries, 0 to 100989
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   datetime_utc  100990 non-null  object
#  1    _conds       100918 non-null  object
#  2    _dewptm      100369 non-null  float64
#  3    _fog         100990 non-null  int64
#  4    _hail        100990 non-null  int64
#  5    _heatindexm  29155 non-null   float64
#  6    _hum         100233 non-null  float64
#  7    _precipm     0 non-null       float64
#  8    _pressurem   100758 non-null  float64
#  9    _rain        100990 non-null  int64
#  10   _snow        100990 non-null  int64
#  11   _tempm       100317 non-null  float64
#  12   _thunder     100990 non-null  int64
#  13   _tornado     100990 non-null  int64
#  14   _vism        96562 non-null   float64
#  15   _wdird       86235 non-null   float64
#  16   _wdire       86235 non-null   object
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# 1        NaN      -9999.0       0       0     28.0          0          0
# 2        NaN      -9999.0       0       0     24.0          0          0
# 3        NaN       1010.0       0       0     24.0          0          0
# 4        NaN       1011.0       0       0     23.0          0          0
#
#     _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# ...

# %%
data.columns = [c.replace('_', '') for c in data.columns]

# %%
data.isnull().sum()
# Out:
# datetimeutc         0
#  conds             72
#  dewptm           621
#  fog                0
#  hail               0
#  heatindexm     71835
#  hum              757
#  precipm       100990
#  pressurem        232
#  rain               0
#  snow               0
#  tempm            673
#  thunder            0
#  tornado            0
#  vism            4428
#  wdird          14755
#  wdire          14755
#  wgustm         99918
#  windchillm    100411
#  wspdm           2358
# dtype: int64

# %%
data.columns = [c.replace(' ', '') for c in data.columns]

# %%
data.head()
# Out:
#       datetimeutc  conds  dewptm  fog  hail  heatindexm   hum  precipm  \
# 0  19961101-11:00  Smoke     9.0    0     0         NaN  27.0      NaN
# 1  19961101-12:00  Smoke    10.0    0     0         NaN  32.0      NaN
# 2  19961101-13:00  Smoke    11.0    0     0         NaN  44.0      NaN
# 3  19961101-14:00  Smoke    10.0    0     0         NaN  41.0      NaN
# 4  19961101-16:00  Smoke    11.0    0     0         NaN  47.0      NaN
#
#    pressurem  rain  snow  tempm  thunder  tornado  vism  wdird  wdire  wgustm  \
# 0     1010.0     0     0   30.0        0        0   5.0  280.0   West     NaN
# 1    -9999.0     0     0   28.0        0        0   NaN    0.0  North     NaN
# 2    -9999.0     0     0   24.0        0        0   NaN    0.0  North     NaN
# 3     1010.0     0     0   24.0        0        0   2.0    0.0  North     NaN
# 4     1011.0     0     0   23.0        0        0   1.2    0.0  North     NaN
#
#    windchillm  wspdm
# 0         NaN    7.4
# 1         NaN    NaN
# ...

# %%
data.corr()['tempm']
# Out:
# dewptm        0.527915
# fog          -0.450534
# hail         -0.002877
# heatindexm    0.726131
# hum          -0.589912
# precipm            NaN
# pressurem     0.004684
# rain         -0.007418
# snow          0.000204
# tempm         1.000000
# thunder       0.000298
# tornado       0.001342
# vism          0.033270
# wdird         0.156525
# wgustm       -0.136216
# windchillm    0.880264
# wspdm         0.224876
# Name: tempm, dtype: float64

# %%
data = data.drop(['fog','precipm','hum','datetimeutc','wdire','conds'],axis=1)

# %%
import seaborn as sns

# %%
sns.distplot(data['tempm'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tempm', ylabel='Density'>

# %%
data.sample(20)
# Out:
#        dewptm  hail  heatindexm  pressurem  rain  snow  tempm  thunder  \
# 27271    23.0     0        32.7      999.0     0     0   29.0        0
# 38904    11.0     0         NaN     1017.0     0     0   25.0        0
# 96440    24.0     0        35.0     1000.0     0     0   30.0        0
# 54740     1.0     0         NaN     1017.0     0     0   23.0        0
# 97683    19.0     0        33.5     1008.0     0     0   32.0        0
# 38835    11.0     0         NaN     1012.0     0     0   26.0        0
# 36409    24.0     0        41.9      998.0     0     0   35.0        0
# 12092     6.0     0         NaN     1004.0     0     0   31.0        0
# 51383     7.0     0         NaN     1017.0     0     0   17.0        0
# 78752    23.0     0         NaN     1009.0     0     0   33.0        0
# 68728    10.0     0         NaN     1011.0     0     0   27.0        0
# 54724     4.0     0         NaN     1019.0     0     0   10.0        0
# ...

# %%
data['rain'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=data['hail'],y=data['tempm'])
# Out:
# <AxesSubplot:xlabel='hail', ylabel='tempm'>

# %%
data['windchillm'].value_counts()
# Out:
# 7.3    86
# 6.2    72
# 6.8    69
# 5.7    45
# 6.4    41
# 6.1    34
# 5.2    31
# 5.0    29
# 4.5    25
# 3.9    25
# 4.0    25
# 4.9    23
# 3.3    22
# 5.8    13
# 3.7    12
# 5.5     9
# 4.3     8
# 2.8     4
# 2.1     3
# 5.3     3
# Name: windchillm, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100990 entries, 0 to 100989
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   dewptm      100369 non-null  float64
#  1   hail        100990 non-null  int64
#  2   heatindexm  29155 non-null   float64
#  3   pressurem   100758 non-null  float64
#  4   rain        100990 non-null  int64
#  5   snow        100990 non-null  int64
#  6   tempm       100317 non-null  float64
#  7   thunder     100990 non-null  int64
#  8   tornado     100990 non-null  int64
#  9   vism        96562 non-null   float64
#  10  wdird       86235 non-null   float64
#  11  wgustm      1072 non-null    float64
#  12  windchillm  579 non-null     float64
#  13  wspdm       98632 non-null   float64
# dtypes: float64(9), int64(5)
# memory usage: 10.8 MB

# %%
data.isnull().sum()
# Out:
# dewptm           621
# hail               0
# heatindexm     71835
# pressurem        232
# rain               0
# snow               0
# tempm            673
# thunder            0
# tornado            0
# vism            4428
# wdird          14755
# wgustm         99918
# windchillm    100411
# wspdm           2358
# dtype: int64

# %%
data['dewptm'] = data['dewptm'].fillna(0).astype(np.int64)
data['dewptm'] = data['dewptm'].astype(np.int64)

# %%
data['heatindexm'] = data['heatindexm'].fillna(0).astype(np.int64)
data['heatindexm'] = data['heatindexm'].astype(np.int64)

data['pressurem'] = data['pressurem'].fillna(0).astype(np.int64)
data['pressurem'] = data['pressurem'].astype(np.int64)

data['tempm'] = data['tempm'].fillna(0).astype(np.int64)
data['tempm'] = data['tempm'].astype(np.int64)

data['vism'] = data['vism'].fillna(0).astype(np.int64)
data['vism'] = data['vism'].astype(np.int64)

data['wdird'] = data['wdird'].fillna(0).astype(np.int64)
data['wdird'] = data['wdird'].astype(np.int64)

data['wgustm'] = data['wgustm'].fillna(0).astype(np.int64)
data['wgustm'] = data['wgustm'].astype(np.int64)

data['windchillm'] = data['windchillm'].fillna(0).astype(np.int64)
data['windchillm'] = data['windchillm'].astype(np.int64)

data['wspdm'] = data['wspdm'].fillna(0).astype(np.int64)
data['wspdm'] = data['wspdm'].astype(np.int64)

# %%
data.isnull().sum()
# Out:
# dewptm        0
# hail          0
# heatindexm    0
# pressurem     0
# rain          0
# snow          0
# tempm         0
# thunder       0
# tornado       0
# vism          0
# wdird         0
# wgustm        0
# windchillm    0
# wspdm         0
# dtype: int64

# %%
data['tempm'].value_counts()
# Out:
# 29    6030
# 28    5596
# 30    5334
# 27    5231
# 31    5061
# 32    4505
# 33    4424
# 26    3891
# 34    3744
# 25    3444
# 35    3283
# 24    2871
# 21    2865
# 23    2767
# 19    2666
# 22    2594
# 15    2553
# 17    2520
# 20    2517
# 18    2425
# 13    2339
# 36    2312
# 16    2274
# 14    2247
# 37    2057
# 12    2022
# 11    1935
# 10    1605
# 38    1433
# 9     1358
# 39    1197
# 8      983
# 40     931
# 7      739
# 41     689
# 0      673
# 42     513
# 43     378
# 6      373
# 44     219
# 5      194
# 45      94
# 4       47
# 46      27
# 47      13
# 3       12
# 72       1
# 63       1
# 1        1
# 62       1
# 90       1
# Name: tempm, dtype: int64

# %%
def Temp(value):
    if(value>=35):
        return 3
    elif(value>=25 and value<35):
        return 2
    else:
        return 1

# %%
data['Target'] = data['tempm'].apply(Temp)

# %%
data.head()
# Out:
#    dewptm  hail  heatindexm  pressurem  rain  snow  tempm  thunder  tornado  \
# 0       9     0           0       1010     0     0     30        0        0
# 1      10     0           0      -9999     0     0     28        0        0
# 2      11     0           0      -9999     0     0     24        0        0
# 3      10     0           0       1010     0     0     24        0        0
# 4      11     0           0       1011     0     0     23        0        0
#
#    vism  wdird  wgustm  windchillm  wspdm  Target
# 0     5    280       0           0      7       2
# 1     0      0       0           0      0       2
# 2     0      0       0           0      0       1
# 3     2      0       0           0      0       1
# 4     1      0       0           0      0       1

# %%
data.sample(10)
# Out:
#        dewptm  hail  heatindexm  pressurem  rain  snow  tempm  thunder  \
# 38047      19     0           0       1008     0     0     23        0
# 15179      22     0          33       1005     0     0     30        0
# 87624      16     0           0       1010     0     0     34        0
# 37927      19     0           0       1011     0     0     25        0
# 10392      25     0          30       1007     0     0     27        0
# 79525      11     0           0       1011     0     0     12        0
# 9679       26     0          46       1001     0     0     36        0
# 64346      24     0           0       1002     0     0     25        0
# 8842       21     0          28       1007     0     0     27        0
# 97535      23     0          35       1003     0     0     31        0
#
#        tornado  vism  wdird  wgustm  windchillm  wspdm  Target
# 38047        0     2    110       0           0      7       1
# ...

# %%
X = data.drop(columns=['tempm','Target'])
Y = data['Target']

# %%
data['heatindexm'].value_counts()
# Out:
# 0     71835
# 30     2374
# 34     2243
# 31     2223
# 36     2152
# 33     2022
# 40     1892
# 35     1855
# 37     1717
# 32     1694
# 39     1676
# 29     1439
# 28     1169
# 38     1145
# 41     1023
# 27      979
# 43      929
# 42      809
# 44      557
# 45      410
# 46      307
# 48      145
# 47      137
# 49       98
# 26       90
# 50       25
# 51       22
# 52       10
# 53        5
# 55        2
# 54        2
# 57        1
# 61        1
# 59        1
# 73        1
# Name: heatindexm, dtype: int64

# %%
data['wspdm'].value_counts()
# Out:
# 0       31763
# 5       10400
# 7       10355
# 9        9430
# 11       8120
#         ...
# 72          1
# 248         1
# 105         1
# 1492        1
# 205         1
# Name: wspdm, Length: 87, dtype: int64

# %%
X
# Out:
#         dewptm  hail  heatindexm  pressurem  rain  snow  thunder  tornado  \
# 0            9     0           0       1010     0     0        0        0
# 1           10     0           0      -9999     0     0        0        0
# 2           11     0           0      -9999     0     0        0        0
# 3           10     0           0       1010     0     0        0        0
# 4           11     0           0       1011     0     0        0        0
# ...        ...   ...         ...        ...   ...   ...      ...      ...
# 100985      17     0           0       1005     0     0        0        0
# 100986      14     0           0       1003     0     0        0        0
# 100987      12     0           0       1002     0     0        0        0
# 100988      15     0           0       1004     0     0        0        0
# 100989      15     0           0       1005     0     0        0        0
#
#         vism  wdird  wgustm  windchillm  wspdm
# ...

# %%
Y
# Out:
# 0         2
# 1         2
# 2         1
# 3         1
# 4         1
#          ..
# 100985    2
# 100986    3
# 100987    3
# 100988    2
# 100989    2
# Name: Target, Length: 100990, dtype: int64

# %%
data.isnull().sum()
# Out:
# dewptm        0
# hail          0
# heatindexm    0
# pressurem     0
# rain          0
# snow          0
# tempm         0
# thunder       0
# tornado       0
# vism          0
# wdird         0
# wgustm        0
# windchillm    0
# wspdm         0
# Target        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100990 entries, 0 to 100989
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   dewptm      100990 non-null  int64
#  1   hail        100990 non-null  int64
#  2   heatindexm  100990 non-null  int64
#  3   pressurem   100990 non-null  int64
#  4   rain        100990 non-null  int64
#  5   snow        100990 non-null  int64
#  6   tempm       100990 non-null  int64
#  7   thunder     100990 non-null  int64
#  8   tornado     100990 non-null  int64
#  9   vism        100990 non-null  int64
#  10  wdird       100990 non-null  int64
#  11  wgustm      100990 non-null  int64
#  12  windchillm  100990 non-null  int64
#  13  wspdm       100990 non-null  int64
#  14  Target      100990 non-null  int64
# dtypes: int64(15)
# memory usage: 11.6 MB

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train.values,y_train)

y_pred=clf.predict(X_test.values)

# %%
clf.predict([[9,0,0,1010,0,0,0,0,5,280,0,0,7.4]])
# Out:
# array([2], dtype=int64)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8637488860283197

# %%
import pickle

# %%
pickle.dump(data,open('data.pkl','wb'))
pickle.dump(clf,open('model.pkl','wb'))

# %%
import bz2file as bz2

# %%
import bz2file as bz2

# %%
def compressed_pickle(title, data):

    with bz2.BZ2File(title + '.pbz2', 'w') as f:
        pickle.dump(data, f)

# %%
compressed_pickle('Newmodel', clf)
